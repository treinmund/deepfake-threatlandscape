# %%
# %matplotlib inline

# Install libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os

# %%
# Set input path
in_path = "~/Documents/2025.1-Deepfake Threat Landscape/2-analysis"

# Load data
df = pd.read_csv(os.path.join(in_path, "threat-actors.csv"))

df = df.drop('Count', axis=1)

# %%
df
# Out:
#                   Threat Actor  Entertain  Experiment  Deceive  Harass  \
# 0                     Activist          0           0        0       0
# 1                       Artist          9           0        0       0
# 2                   Influencer          0           0        0       1
# 3                  News outlet          2           0        1       0
# 4                 Nation state          0           0        2       0
# 5              Political party          0           0        0       1
# 6                   Politician          1           0        0       0
# 7              Private company         17           3        5       2
# 8   Private individual - adult          6           1        3       2
# 9   Private individual - minor          3           1        1       5
# 10                    Scammers          1           0       36       0
# 11            Sexual Exploiter          5           0        0       4
# 12                    Satirist          6           0        0       1
# 13                     Unknown          5           1        6       7
#
#     Influence  Financial  Political  Sexual  Social  Yes  No  Individual  \
# 0           5          0          5       0       0    4   1           4
# 1           0          2          0       0       6    3   6           3
# 2           0          0          0       0       1    1   0           1
# 3           5          1          6       0       1    6   2           0
# 4           8          1          9       0       0   10   0           0
# 5           6          0          7       0       0    5   1           0
# 6           3          0          4       0       0    4   0           4
# 7           5         27          3       4       0   21  13           2
# 8           2          4          1       4       4   13   2          12
# 9           0          0          1       2       2    8   2           4
# 10          0         37          0       0       0   37   0          10
# 11          0          0          0       8       0    7   2           4
# 12          3          0          3       0       4    6   3           7
# 13         10          3         13       9       2   23   0           3
#
#     Group  Institution  Rudimentary  Sophisticated
# 0       1            0            5              0
# 1       6            0            6              3
# 2       0            0            1              0
# 3       2            6            5              4
# 4       0           10            4              6
# 5       3            4            4              3
# 6       0            0            4              0
# 7       1           30           24             11
# 8       3            0           11              5
# 9       5            0           10              0
# 10     22            0            4             33
# 11      5            0            9              0
# 12      2            0           10              0
# 13      0            0           23             10

# %%
# Define column groups
goal_cols = ["Entertain", "Experiment", "Deceive", "Harass", "Influence"]
motive_cols = ["Financial", "Political", "Sexual", "Social"]
harm_cols = ["Yes", "No"]
org_cols = ["Individual", "Group", "Institution"]
soph_cols = ["Rudimentary", "Sophisticated"]

# Column to group mapping
column_to_group = {
    "Entertain": "Goal",
    "Experiment": "Goal",
    "Deceive": "Goal",
    "Harass": "Goal",
    "Influence": "Goal",

    "Financial": "Motive",
    "Political": "Motive",
    "Sexual": "Motive",
    "Social": "Motive",

    "Yes": "Harm Awareness",
    "No": "Harm Awareness",

    "Individual": "Organization",
    "Group": "Organization",
    "Institution": "Organization",

    "Rudimentary": "Sophistication",
    "Sophisticated": "Sophistication",
}

# %%
# Column-group normalization
def normalize_group(df, cols):
    df = df.copy()
    row_totals = df[cols].sum(axis=1)
    df[cols] = df[cols].div(row_totals.replace(0, np.nan), axis=0)
    df[cols] = df[cols].fillna(0)
    return df

df_norm = df.copy()

for cols in [goal_cols, motive_cols, harm_cols, org_cols, soph_cols]:
    df_norm = normalize_group(df_norm, cols)

# %%
# Reshape
df_long = (
    df_norm
    .melt(
        id_vars="Threat Actor",
        var_name="Dimension",
        value_name="Value"
    )
)

df_long["Group"] = df_long["Dimension"].map(column_to_group)

df_long["Group"] = pd.Categorical(df_long["Group"], categories=df_long["Group"].unique())

# %%
# Order the threat actors
actor_order = [
    "Private individual - minor",
    "Private individual - adult",
    "Artist",
    "Satirist",
    "Influencer",
    "Sexual Exploiter",
    "Scammers",
    "Activist",
    "Politician",
    "Political party",
    "News outlet",
    "Private company",
    "Nation state",
    "Unknown"
]

df_long["Threat Actor"] = pd.Categorical(
    df_long["Threat Actor"],
    categories=actor_order,
    ordered=True
)

# %%
# Faceted heat map
groups = df_long["Group"].unique()

fig, axes = plt.subplots(
    1, len(groups),
    figsize=(16, 6),
    sharey=True,
    gridspec_kw={"wspace": 0.05}
)

cmap = sns.light_palette("#2E8B57", as_cmap=True)

for ax, group in zip(axes, groups):
    subset = df_long[df_long["Group"] == group]
    pivot = subset.pivot(
        index="Threat Actor",
        columns="Dimension",
        values="Value"
    )

    sns.heatmap(
        pivot,
        ax=ax,
        cmap=cmap,
        vmin=0,
        vmax=1,
        cbar=(ax == axes[-1]),
        linewidths=0.3,
        linecolor="white"
    )

    ax.set_title(group, fontsize=11, fontweight="bold")
    ax.set_xlabel("")
    ax.set_ylabel("")

    ax.tick_params(axis="x", rotation=45, labelsize=9)
    ax.tick_params(axis="y", labelsize=9)

# Colorbar label
cbar = axes[-1].collections[0].colorbar
cbar.set_label("Row-normalized proportion", fontsize=10)

plt.show()

# %%
df_long.sort_values(by=["Threat Actor", "Group"])
# Out:
#                    Threat Actor      Dimension    Value           Group
# 9    Private individual - minor      Entertain  0.30000            Goal
# 23   Private individual - minor     Experiment  0.10000            Goal
# 37   Private individual - minor        Deceive  0.10000            Goal
# 51   Private individual - minor         Harass  0.50000            Goal
# 65   Private individual - minor      Influence  0.00000            Goal
# ..                          ...            ...      ...             ...
# 167                     Unknown     Individual  1.00000    Organization
# 181                     Unknown          Group  0.00000    Organization
# 195                     Unknown    Institution  0.00000    Organization
# 209                     Unknown    Rudimentary  0.69697  Sophistication
# 223                     Unknown  Sophisticated  0.30303  Sophistication
#
# [224 rows x 4 columns]
