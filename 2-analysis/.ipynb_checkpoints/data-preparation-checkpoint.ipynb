# %% [markdown]
# # Prepare Data for Manual Analysis

# %%
# Load libraries
import pandas as pd
import os
import numpy as np
import ast

# %%
# Set file path
in_path = '/Users/tylund/Library/CloudStorage/Dropbox/1. Side Projects/2025.1-Deepfake Threat Landscape/1-data/'

# Import data
aiid_deepfakes = pd.read_csv(os.path.join(in_path, 'deepfake-incidents/aiid_gpt_results.csv'))
aaic_deepfakes = pd.read_csv(os.path.join(in_path, 'deepfake-incidents/aaic_gpt_results.csv'))

# %%
# Drop irrelevant columns
cols_to_drop = ['is_deepfake', 'comment', 'gpt_classification', 'match', 'final']

# Filter on incidents that passed selection
aiid_deepfakes = aiid_deepfakes[aiid_deepfakes['final']].drop(cols_to_drop, axis=1)
aaic_deepfakes = aaic_deepfakes[aaic_deepfakes['final']].drop(cols_to_drop, axis=1)

# %% [markdown]
# ### AIID Preparation

# %%
aiid_incidents = pd.read_csv(os.path.join(in_path, 'incident-repos/AIID-repository-09042025/incidents.csv'))
aiid_cset = pd.read_csv(os.path.join(in_path, 'incident-repos/AIID-repository-09042025/classifications_CSETv1.csv'))
aiid_reports = pd.read_csv(os.path.join(in_path, 'incident-repos/AIID-repository-09042025/reports.csv'))

# %%
aiid_incidents = aiid_incidents.drop(columns=['_id', 'description', 'title']).rename(
    columns={'Alleged deployer of AI system': 'deployer',
             'Alleged developer of AI system': 'developer',
             'Alleged harmed or nearly harmed parties': 'target'}
)

# %%
aiid_deepfakes = pd.merge(aiid_deepfakes, aiid_incidents, on='incident_id', how='left')

# %%
aiid_cset = aiid_cset[['Incident ID', 'Location Country (two letters)', 'Sector of Deployment']].rename(
    columns = {'Incident ID': 'incident_id',
               'Location Country (two letters)': 'location',
               'Sector of Deployment': 'sector'}
)

# %%
aiid_deepfakes = pd.merge(aiid_deepfakes, aiid_cset, on='incident_id', how='left')

# %%
aiid_deepfakes
# Out:
#      incident_id                                              title  \
# 0            943  Nonconsensual Explicit AI-Generated Images of ...
# 1            976  AI-Generated OB-GYN Health Influencers on TikT...
# 2            974  Deepfake Audio Impersonates U.S. Secretary of ...
# 3            973  Canadian Fraud Ring Allegedly Used AI Voice Cl...
# 4            972  Russian Influence Operation Allegedly Uses AI ...
# ..           ...                                                ...
# 313          737  Amandine Le Pen Deepfake Account Misleads Thou...
# 314          754  British Female Politicians Victimized by Deepf...
# 315          755  Deepfake Targets Olena Zelenska in Russian Dis...
# 316          147  Snippet Text: AI voice cloning is used in a hu...
# 317          200  Snippet Text: Criminals used artificial intell...
#
#                                            description  \
# 0    AI-generated explicit images of up to 60 femal...
# 1    AI-generated avatars posing as OB-GYNs on TikT...
# 2    A deepfake audio clip impersonating U.S. Secre...
# 3    A Canadian fraud ring allegedly used AI-genera...
# 4    A Russian disinformation campaign, linked to S...
# ..                                                 ...
# 313  A TikTok account, "Amandine Le Pen," created u...
# 314  British female politicians, including Angela R...
# 315  A deepfake video falsely suggesting that Olena...
# 316                                                NaN
# 317                                                NaN
#
#                justification        date                          reports  \
# 0                  Agreement  2025-02-20                           [4776]
# 1    Fully synthetic persona  2025-03-08       [4935,4983,4984,4985,4986]
# 2                  Agreement  2025-03-04                           [4933]
# 3                  Agreement  2025-03-05  [4923,4924,4925,4926,4927,4928]
# 4                  Agreement  2024-09-25                      [4920,4921]
# ..                       ...         ...                              ...
# 313                Agreement  2024-04-16                      [3962,3981]
# 314                Agreement  2024-07-01                      [3989,5592]
# 315                Agreement  2024-07-03       [3990,4014,4881,4897,4899]
# 316                Agreement  2020-01-15  [1496,1497,5135,5136,5137,5138]
# 317                Agreement  2019-03-01                           [1653]
#
#                                               deployer  \
# 0    ["two-unidentified-year-11-students-at-gladsto...
# 1                             ["unknown-tiktok-users"]
# 2                    ["unknown-disinformation-actors"]
# 3    ["scammers","fraudsters","canadian-fraud-ring-...
# 4    ["storm-1516","john-mark-dougan","russian-stat...
# ..                                                 ...
# 313                            ["unknown-tiktok-user"]
# 314                      ["unknown-deepfake-creators"]
# 315  ["verite-cachee-france","russian-linked-disinf...
# 316  ["unknown-transnational-fraud-ring","unknown-s...
# 317                                       ["scammers"]
#
#                                              developer  \
# 0            ["unknown-deepfake-technology-developer"]
# 1                                         ["captions"]
# 2                 ["unknown-voice-cloning-technology"]
# 3       ["unknown-voice-cloning-technology-developer"]
# 4    ["unknown-deepfake-technology-developer","unkn...
# ..                                                 ...
# 313                      ["unknown-deepfake-creators"]
# 314                      ["unknown-deepfake-creators"]
# 315                      ["unknown-deepfake-creators"]
# 316  ["unknown-voice-cloning-technology-developer",...
# 317                                        ["unknown"]
#
#                                                 target location  \
# 0    ["up-to-60-unnamed-students-at-gladstone-park-...      NaN
# 1                                     ["tiktok-users"]      NaN
# 2    ["truth","relations-between-the-united-states-...      NaN
# 3    ["grandparents-targeted-by-canadian-fraud-ring...      NaN
# 4    ["kamala-harris","american-voters","electoral-...      NaN
# ..                                                 ...      ...
# 313          ["le-pen-family","french-general-public"]      NaN
# 314  ["stella-creasy","priti-patel","penny-mordaunt...      NaN
# 315  ["olena-zelenska","volodymyr-zelenskyy","gover...      NaN
# 316  ["unnamed-japanese-firm","unnamed-hong-kong-ba...       CN
# 317             ["unnamed-uk-based-energy-firm's-ceo"]      NaN
#
#                                         sector
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ..                                         ...
# 313                                        NaN
# 314                                        NaN
# 315                                        NaN
# 316  financial and insurance activities, other
# 317                                        NaN
#
# [318 rows x 11 columns]

# %%
aiid_report_numbers = aiid_deepfakes[['incident_id', 'reports']]
aiid_report_numbers['reports'] = aiid_report_numbers['reports'].apply(ast.literal_eval)
aiid_report_numbers = aiid_report_numbers.explode('reports', ignore_index=True).rename(columns={'reports':'report_number'})
# Out:
# /var/folders/8s/cfflhf8d07l30rhm7gr5cj2w0000gp/T/ipykernel_18687/2690516346.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aiid_report_numbers['reports'] = aiid_report_numbers['reports'].apply(ast.literal_eval)

# %%
# Filter only English reports
aiid_reports = aiid_reports[aiid_reports['language'] == 'en']

aiid_reports = aiid_reports[['report_number', 'text', 'title', 'source_domain']]

# %%
aiid_report_df = pd.merge(aiid_report_numbers, aiid_reports, on='report_number', how='left').dropna(subset='text')

# %%
aiid_report_df['details'] = aiid_report_df['title'].fillna('') + '; ' + aiid_report_df['source_domain'].fillna('') + '\n\n' + aiid_report_df['text'].fillna('')

# %%
aiid_report_df = aiid_report_df[['incident_id', 'details']]

aiid_merged_reports = aiid_report_df.groupby('incident_id', as_index=False).agg({'details': '\n\n'.join})

# %%
aiid_merged_reports
# Out:
#      incident_id                                            details
# 0             39  Fake Obama created using AI tool to make phone...
# 1            147  Bank Robbers Steal $35 Million by Deepfaking B...
# 2            198  Russian War Report: Hacked news program and de...
# 3            200  Fraudsters Used AI to Mimic CEO’s Voice in Unu...
# 4            201  XR Belgium posts deepfake of Belgian premier l...
# ..           ...                                                ...
# 305         1165  Grok generates fake Taylor Swift nudes without...
# 306         1168  False claim of UK colonels captured in Ukraine...
# 307         1170  Chris Cuomo mocked for response after falling ...
# 308         1175  Jessica Radcliffe Orca Incident A Hoax: The Tr...
# 309         1185  Kim Seon-ho’s agency warns against impersonati...
#
# [310 rows x 2 columns]

# %%
aiid_deepfakes = pd.merge(aiid_deepfakes, aiid_merged_reports, on='incident_id', how='left')

# %%
aiid_deepfakes
# Out:
#      incident_id                                              title  \
# 0            943  Nonconsensual Explicit AI-Generated Images of ...
# 1            976  AI-Generated OB-GYN Health Influencers on TikT...
# 2            974  Deepfake Audio Impersonates U.S. Secretary of ...
# 3            973  Canadian Fraud Ring Allegedly Used AI Voice Cl...
# 4            972  Russian Influence Operation Allegedly Uses AI ...
# ..           ...                                                ...
# 313          737  Amandine Le Pen Deepfake Account Misleads Thou...
# 314          754  British Female Politicians Victimized by Deepf...
# 315          755  Deepfake Targets Olena Zelenska in Russian Dis...
# 316          147  Snippet Text: AI voice cloning is used in a hu...
# 317          200  Snippet Text: Criminals used artificial intell...
#
#                                            description  \
# 0    AI-generated explicit images of up to 60 femal...
# 1    AI-generated avatars posing as OB-GYNs on TikT...
# 2    A deepfake audio clip impersonating U.S. Secre...
# 3    A Canadian fraud ring allegedly used AI-genera...
# 4    A Russian disinformation campaign, linked to S...
# ..                                                 ...
# 313  A TikTok account, "Amandine Le Pen," created u...
# 314  British female politicians, including Angela R...
# 315  A deepfake video falsely suggesting that Olena...
# 316                                                NaN
# 317                                                NaN
#
#                justification        date                          reports  \
# 0                  Agreement  2025-02-20                           [4776]
# 1    Fully synthetic persona  2025-03-08       [4935,4983,4984,4985,4986]
# 2                  Agreement  2025-03-04                           [4933]
# 3                  Agreement  2025-03-05  [4923,4924,4925,4926,4927,4928]
# 4                  Agreement  2024-09-25                      [4920,4921]
# ..                       ...         ...                              ...
# 313                Agreement  2024-04-16                      [3962,3981]
# 314                Agreement  2024-07-01                      [3989,5592]
# 315                Agreement  2024-07-03       [3990,4014,4881,4897,4899]
# 316                Agreement  2020-01-15  [1496,1497,5135,5136,5137,5138]
# 317                Agreement  2019-03-01                           [1653]
#
#                                               deployer  \
# 0    ["two-unidentified-year-11-students-at-gladsto...
# 1                             ["unknown-tiktok-users"]
# 2                    ["unknown-disinformation-actors"]
# 3    ["scammers","fraudsters","canadian-fraud-ring-...
# 4    ["storm-1516","john-mark-dougan","russian-stat...
# ..                                                 ...
# 313                            ["unknown-tiktok-user"]
# 314                      ["unknown-deepfake-creators"]
# 315  ["verite-cachee-france","russian-linked-disinf...
# 316  ["unknown-transnational-fraud-ring","unknown-s...
# 317                                       ["scammers"]
#
#                                              developer  \
# 0            ["unknown-deepfake-technology-developer"]
# 1                                         ["captions"]
# 2                 ["unknown-voice-cloning-technology"]
# 3       ["unknown-voice-cloning-technology-developer"]
# 4    ["unknown-deepfake-technology-developer","unkn...
# ..                                                 ...
# 313                      ["unknown-deepfake-creators"]
# 314                      ["unknown-deepfake-creators"]
# 315                      ["unknown-deepfake-creators"]
# 316  ["unknown-voice-cloning-technology-developer",...
# 317                                        ["unknown"]
#
#                                                 target location  \
# 0    ["up-to-60-unnamed-students-at-gladstone-park-...      NaN
# 1                                     ["tiktok-users"]      NaN
# 2    ["truth","relations-between-the-united-states-...      NaN
# 3    ["grandparents-targeted-by-canadian-fraud-ring...      NaN
# 4    ["kamala-harris","american-voters","electoral-...      NaN
# ..                                                 ...      ...
# 313          ["le-pen-family","french-general-public"]      NaN
# 314  ["stella-creasy","priti-patel","penny-mordaunt...      NaN
# 315  ["olena-zelenska","volodymyr-zelenskyy","gover...      NaN
# 316  ["unnamed-japanese-firm","unnamed-hong-kong-ba...       CN
# 317             ["unnamed-uk-based-energy-firm's-ceo"]      NaN
#
#                                         sector  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ..                                         ...
# 313                                        NaN
# 314                                        NaN
# 315                                        NaN
# 316  financial and insurance activities, other
# 317                                        NaN
#
#                                                details
# 0    Police investigate sexually explicit deepfake ...
# 1    AI-generated ‘doctors’ are duping TikTok users...
# 2    Fake Marco Rubio audio on Starlink, Ukraine sp...
# 3    Dozens of Canadians are charged for scamming A...
# 4    Russia Targets Harris with Rhino-Shooting Hoax...
# ..                                                 ...
# 313  Qui est Amandine Le Pen, ce deepfake au servic...
# 314  British female politicians targeted by fake po...
# 315  Deepfake video targeting Zelensky’s wife linke...
# 316  Bank Robbers Steal $35 Million by Deepfaking B...
# 317  Fraudsters Used AI to Mimic CEO’s Voice in Unu...
#
# [318 rows x 12 columns]

# %%
aiid_deepfakes.to_csv(os.path.join(in_path, 'deepfake-incidents/aiid_dataset_for_analysis.csv'), index=False, encoding='utf-8')

# %% [markdown]
# ## AIAAIC Preparation

# %%
# Import web data
aaic_webpages = pd.read_csv(os.path.join(in_path, 'web-data/aaic_webpages.csv')).drop(
    columns=['success', 'title', 'text_length', 'elapsed_time', 'error', 'URL']
)

aaic_repo = pd.read_csv(os.path.join(in_path, 'deepfake-incidents/aaic_deepfakes.csv')).drop(
    columns=['Headline', 'System', 'Technology', 'Link', 'is_deepfake', 'comment']
).rename(columns={
    'Incident_ID': 'incident_id',
    'Date': 'date',
    'Country': 'location',
    'Sector': 'sector',
    'Deployer': 'deployer',
    'Developer': 'developer'
})

# %%
aaic_dataset = pd.merge(aaic_deepfakes, aaic_webpages, on='incident_id', how='left')

aaic_dataset = pd.merge(aaic_dataset, aaic_repo, on='incident_id', how='left')

# %%
aaic_dataset.to_csv(os.path.join(in_path, 'deepfake-incidents/aaic_dataset_for_analysis.csv'), index=False, encoding='utf-8')
